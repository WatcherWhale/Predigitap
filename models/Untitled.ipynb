# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
acc_wz = [0.9236, 0.6549, 0.6028, 0.5102, 0.6441, 0.6680]
acc_nz = [0.9345, 0.6622, 0.6421, 0.5736, 0.6638, 0.6615]

# %%
plt.bar([i - 0.2 for i in range(6)],np.array(acc_wz) * 100, width=0.4, label="With zero results")
plt.bar([i + 0.2 for i in range(6)],np.array(acc_nz) * 100, width=0.4, label="Without zero results")
#plt.plot([i for i in range(6)], [66 for i in range(6)], color="orange")
plt.xticks([i for i in range(6)], 
           ["Web Technology 1", "Data Networks", "Routing & Switching", "Kinderwens 1", "Kinderwens 2", "Web Technology 2"],
          rotation="vertical")
plt.ylabel("Accuracy (%)")
plt.legend()
plt.title("Accuracy per Course")
# Out:
# Text(0.5, 1.0, 'Accuracy per Course')
